# %%
from selenium import webdriver
from scrapy import Selector
from selenium.webdriver.chrome.service import Service
import pandas as pd

from webdriver_manager.chrome import ChromeDriverManager
import time
import random

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
URL = "https://www.facebook.com/groups/faireretailers"
driver.get(URL)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/terryzeng/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache

# %%
#sel = Selector(text=driver.page_source)
#list = sel.css('[class="j83agx80 cbu4d94t ew0dbk1b irj2b8pg"]').css('[class="nc684nl6"]').css('[role="link"]').css('a::attr(href)').getall()
#name_list = sel.css('[class="j83agx80 cbu4d94t ew0dbk1b irj2b8pg"]').css('[class="nc684nl6"]').css('[role="link"]::text').getall()

#container = sel.css('[class="j83agx80 cbu4d94t ew0dbk1b irj2b8pg"]').css('[class="nc684nl6"]').getall()

# %%
print(len(list))
print(len(name_list))
#print(len(container))
# Out:
# 2111
# 2111

# %%
raw_dict = dict(zip(name_list,list))

# %%
df_raw = pd.DataFrame(raw_dict, index=[0])
df_raw.to_csv("faire_fb_raw.csv")

# %%
#scrape pages
for i in range(500):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /var/folders/jp/4n2c9lxx3k9c9bvs42tgmwzc0000gn/T/ipykernel_1014/1925242496.py in <module>
#       1 #scrape pages
#       2 for i in range(500):
# ----> 3     driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#       4     time.sleep(2)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     632             command = Command.EXECUTE_SCRIPT
#     633
# --> 634         return self.execute(command, {
#     635             'script': script,
#     636             'args': converted_args})['value']
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# ...

# %%
sel = Selector(text=driver.page_source)
post_name = sel.css('[class="du4w35lb k4urcfbm l9j0dhe7 sjgh65i0"]').xpath('//span[@class="nc684nl6"]/a/strong/span/text()').getall()
post_text = sel.css('[class="du4w35lb k4urcfbm l9j0dhe7 sjgh65i0"]').css('[class="kvgmc6g5 cxmmr5t8 oygrvhab hcukyx3x c1et5uql ii04i59q"] *::text').getall()
#post_date

# %%
for post in sel.css('[class="du4w35lb k4urcfbm l9j0dhe7 sjgh65i0"]'):
    text = ("").join(post.css('[class="kvgmc6g5 cxmmr5t8 oygrvhab hcukyx3x c1et5uql ii04i59q"] *::text').getall())    
    #if text =='':
    #    text = post.css('[class="hv4rvrfc dati1w0a jb3vyjys qt6c0cv9"]::text').get()

    items = {
        #'author': post.xpath('//span[@class="nc684nl6"]/a/strong/span/text()').get(),
        'post' : text
    }
    print(items)
# Out:
# {'post': 'A word of warning if you use Shopify POS and scan your product UPC/barcodes - and have upgraded to v.7 of the POS app as we have. Prior to this release, scanning a product in your inventory that shares UPC codes (for example, a product with several variants) , would result in a list of those products for you to choose from.  With this new release, the POS picks the first variant and adds it to the cart - and does not provide the aforementioned list.  We figured out this was… See more'}
# {'post': ''}
# {'post': 'Just bought an old coca-cola cooler. Looking for bestselling old fashioned sodas and drinks?'}
# {'post': ''}
# {'post': ''}
# {'post': ''}
# {'post': ''}
# {'post': "Why have I just received a boatload of emails from Faire vendors with $100 promo for new retailers? They are cluttering up my inbox. I ALREADY have an account. Can't Faire weed out current accounts so we don't get bombarded by unnecessary communications? I mean, come on..."}

# %%
dict(zip(post_name,post_text))
# Out:
# {'Howard Aspinwall': 'Looking for cute summer dresses that are not imported. When I use the "Made in USA" filter, it bypasses where they are made from if it is shipped from the USA.',
#  'Roberta D Moore': 'Those that have a brick and mortar, can you give me some information on how you create barcodes and what POS system you use? ',
#  'Lisa Spiegel Schulte': '(I do not have Shopify or any online shop this will all be in person)',
# ...

# %%
post_text
# Out:
# ['A word of warning if you use Shopify POS and scan your product UPC/barcodes - and have upgraded to v.7 of the POS app as we have. ',
#  'Prior to this release, scanning a product in your inventory that shares UPC codes (for example, a product with several variants) , would result in a list of those products for you to choose from.  ',
#  'With this new release, the POS picks the first variant and adds it to the cart - and does not provide the aforementioned list.  We figured out this was happening for several days and now have an inventory nightmare on our hands.',
# ...

# %%
# %history
# Out:
# from selenium import webdriver
# from scrapy import Selector
# from selenium.webdriver.chrome.service import Service
# import pandas as pd
#
# from webdriver_manager.chrome import ChromeDriverManager
# import time
# import random
# driver = webdriver.Chrome(ChromeDriverManager().install())
# URL = "file:///Users/terryzeng/Downloads/(2)%20Faire%20Retailer%20Community%20_%20Facebook.html"
# driver.get(URL)
# sel = Selector(text=driver.page_source)
# #list = sel.css('[class="nc684nl6"]').css('[role="link"]').css('a::attr(href)').getall()
# #name_list = sel.css('[class="nc684nl6"]').css('[role="link"]::text').getall()
#
# container = sel.css('[class="j83agx80 cbu4d94t ew0dbk1b irj2b8pg"]').css('[class="nc684nl6"]').getall()
# from selenium import webdriver
# from scrapy import Selector
# from selenium.webdriver.chrome.service import Service
# import pandas as pd
#
# from webdriver_manager.chrome import ChromeDriverManager
# import time
# import random
# ...
