# %%
# Imports
import numpy as np
import pandas as pd
import pyspark
from google.cloud import bigquery

# %%
client = bigquery.Client(location="US")
print("Client creating using default project: {}".format(client.project))

client = bigquery.Client(location="US", project="helio-staging")
# Out:
# Client creating using default project: helio-staging

# %%
rev_source = ["sephora","ulta"]

job_config = bigquery.QueryJobConfig(
        query_parameters=[
            bigquery.ArrayQueryParameter("revSource", "STRING", rev_source)
        ]
)
max_date_query = """
    SELECT DISTINCT execution_date
    FROM `helio-staging.online_reviews.online_reviews__deduped_review__1_0`
    where execution_date > DATE_ADD(current_date(), INTERVAL -10 DAY)
    and normalized_url IS NOT NULL
    ORDER BY execution_date DESC
    LIMIT 2
    """
query_job = client.query(
    max_date_query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
    job_config=job_config
)  # API request - starts the query

#max_date = query_job.to_dataframe()['f0_'].astype('str')[0]

# %%
max_date

# %%
qj = query_job.to_dataframe()
max_date, prev_date = qj["execution_date"].astype('str')[0],qj["execution_date"].astype('str')[1]

# %%
max_date = '2022-03-20'

# %%
prev_date = '2022-03-19'

# %%
job_config = bigquery.QueryJobConfig(
    query_parameters=[
        bigquery.ScalarQueryParameter("max_date", "STRING", max_date),
        bigquery.ArrayQueryParameter("revSource", "STRING", rev_source)
    ]
)
review_query = """
    SELECT distinct source_name,
    normalized_url,
    FROM `helio-staging.online_reviews.online_reviews__deduped_review__1_0`
    WHERE source_name in UNNEST (@revSource)
    AND normalized_url IS NOT NULL
    AND execution_date = @max_date
    """
query_job = client.query(
    review_query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
    job_config=job_config
)  # API request - starts the query

brands = query_job.to_dataframe()
brands = brands.loc[brands.astype(str).drop_duplicates().index]
brands["combined"] = brands["source_name"] +" "+brands["normalized_url"] 
brands = brands["combined"].tolist()

# %%
brands
# Out:
# ['ulta gobareoutside.com',
#  'ulta holsterbrands.com',
#  'sephora caliraybeauty.com',
#  'ulta oseamalibu.com',
#  'ulta cocokind.com',
#  'sephora algenist.com',
#  'ulta alternahaircare.com',
#  'ulta tonymoly.us',
#  'ulta volitionbeauty.com',
#  'ulta vincecamuto.com',
#  'ulta hairology.com',
#  'sephora cleanbeauty.com',
#  'ulta rebelsrefinery.com',
#  'ulta redcarpetmanicure.com',
#  'sephora golde.co',
#  'ulta nablacosmetics.com',
#  'ulta lakeandskye.com',
#  'ulta honest.com',
#  'ulta mizani.com',
#  'ulta carbontheory.com',
#  'sephora captainblankenship.com',
#  'sephora eadem.co',
#  'ulta getjackblack.com',
#  'ulta goodalcosmetic.com',
#  'ulta unwash.com',
#  'ulta thevintagecosmeticcompany.com',
#  'sephora deborahlippmann.com',
#  'ulta brite.com',
#  'ulta virtuelabs.com',
#  'sephora balenciaga.com',
#  'sephora foursigmatic.com',
#  'ulta locksandmane.com',
#  'ulta sweetspotlabs.com',
#  'ulta sweetspot.com',
#  'ulta thefoxtan.com',
#  'ulta hyntbeauty.com',
#  'sephora urbandecay.com',
#  'sephora peterthomasroth.com',
#  'ulta life-flo.com',
#  'sephora mariobadescu.com',
#  'sephora prima.co',
#  'sephora nudestix.com',
#  'ulta botanics.co.uk',
#  'sephora indielee.com',
#  'ulta impressionsvanity.com',
#  'ulta edhardyoriginals.com',
#  'sephora byrosiejane.com',
#  'ulta escada.com',
#  'sephora josiemaran.com',
#  'ulta tantowel.com',
#  'sephora graceeleyae.com',
#  'ulta myrealchemistry.com',
#  'ulta wella.com',
#  'sephora skinlaundry.com',
#  'ulta spotlightoralcare.com',
#  'sephora gisou.com',
#  'ulta lacoste.com',
#  'ulta karunaskin.com',
#  'ulta socozy.com',
#  'ulta terrabeautybars.com',
#  'sephora necessaire.com',
#  'ulta clairol.com',
#  'ulta theluvscrub.com',
#  'sephora shhhowercap.com',
#  'ulta pursomalife.com',
#  'ulta buddyscrub.com.au',
#  'ulta australiangold.com',
#  'ulta skingymco.com',
#  'sephora grandecosmetics.com',
#  'sephora benefitcosmetics.com',
#  'ulta origins.com',
#  'sephora dtrtapparel.com',
#  'sephora versace.com',
#  'sephora kncbeauty.com',
#  'sephora tataharperskincare.com',
#  'sephora buxomcosmetics.com',
#  'ulta everymanjack.com',
#  'ulta muglerusa.com',
#  'ulta dottedzebra.com',
#  'sephora anastasiabeverlyhills.com',
#  'ulta moschino.com',
#  'ulta nads.com',
#  'sephora tocca.com',
#  'sephora toofaced.com',
#  'sephora lorealprofessionnel.com',
#  'sephora itcosmetics.com',
#  'sephora crushedtonic.com',
#  'sephora reverie.com',
#  'sephora calvinklein.us',
#  'ulta toocoolforschool.us',
#  'sephora dolcegabbana.com',
#  'ulta naturelab.com',
#  'ulta naircare.com',
#  'sephora skinfix.com',
#  'sephora otherland.com',
#  'ulta scentbeauty.com',
#  'ulta paulmitchell.com',
#  'ulta skinkick.com',
#  'sephora makeuperaser.com',
#  'ulta foxybae.com',
#  'sephora peaceoutskincare.com',
#  'sephora ghdhair.com',
#  'ulta systemprofessional.com',
#  'ulta meleskincare.com',
#  'ulta allsaints.com',
#  'ulta beautygarde.com',
#  'ulta cnd.com',
#  'ulta scunci.com',
#  'sephora dermadoctor.com',
#  'ulta wakse.com',
#  'sephora fableandmane.com',
#  'ulta madison-reed.com',
#  'ulta lovingtan.com',
#  'sephora qhemetbiologics.com',
#  'ulta grandecosmetics.com',
#  'sephora mdsolarsciences.com',
#  'ulta jimmychoo.com',
#  'ulta parissa.com',
#  'ulta lauramercier.com',
#  'ulta morgantaylorlacquer.com',
#  'sephora alpha-h.com',
#  'ulta kenraprofessional.com',
#  'ulta clarinsusa.com',
#  'sephora laneige.com',
#  'ulta nkdskn.com',
#  'ulta orgain.com',
#  'ulta rocskincare.com',
#  'sephora patmcgrath.com',
#  'ulta frankbody.com',
#  'sephora cayskin.com',
#  'sephora anthony.com',
#  'ulta simplehuman.com',
#  'ulta finchberry.com',
#  'ulta boscia.com',
#  'sephora charlottetilbury.com',
#  'ulta dove.com',
#  'ulta fourreasons.us',
#  'ulta joshrosebrook.com',
#  'ulta narcisorodriguez.com',
#  'ulta mynuface.com',
#  'ulta no7beauty.com',
#  'ulta nexxus.com',
#  'sephora bioeffect.com',
#  'ulta kristinesshair.com',
#  'sephora philosophy.com',
#  'sephora taste-beauty.com',
#  'ulta lottie.london',
#  'ulta babylisspro.com',
#  'ulta lunatabeauty.com',
#  'ulta meetalleyoop.com',
#  'sephora slip.com',
#  'sephora dermarche.com',
#  'sephora byartis.com',
#  'sephora johnvarvatos.com',
#  'sephora gucci.com',
#  'sephora memebox.com',
#  'sephora sundayriley.com',
#  'ulta sttropeztan.com',
#  'ulta benefitcosmetics.com',
#  'ulta uberliss.com',
#  'sephora murad.com',
#  'sephora fresh.com',
#  'ulta earthsnectar.com',
#  'ulta manicpanic.com',
#  'ulta blindbarber.com',
#  'ulta azzaro.com',
#  'ulta ahava.com',
#  'sephora evian.com',
#  'sephora omorovicza.com',
#  'sephora devacurl.com',
#  'ulta laroche-posay.us',
#  'ulta laurageller.com',
#  'sephora mycanopy.org',
#  'sephora pacorabanne.com',
#  'ulta ohklife.com',
#  'ulta pixibeauty.com',
#  'ulta juicebeauty.com',
#  'ulta kissonline.com',
#  'ulta moonmousse.com',
#  'sephora montblanc.com',
#  'ulta aquaphorus.com',
#  'sephora shopvioletvoss.com',
#  'sephora alternahaircare.com',
#  'sephora milkmakeup.com',
#  'ulta dereklam.com',
#  'ulta elchim.com',
#  'ulta bodybenefitswoodlands.com',
#  'ulta drbrandtskincare.com',
#  'ulta lovebeautyandplanet.com',
#  'sephora onesizebeauty.com',
#  'ulta myvitabath.com',
#  'sephora mytopicals.com',
#  'sephora wellkeptbeauty.com',
#  'ulta trilogyproducts.com',
#  'ulta skyniceland.com',
#  'sephora etatlibredorange.com',
#  'ulta karinadresses.com',
#  'ulta zinodavidoff.com',
#  'sephora amazingcosmetics.com',
#  'sephora kohgendocosmetics.com',
#  'ulta haute-bronze.com',
#  'ulta goli.com',
#  'ulta keracolorhair.com',
#  'ulta nailtopia.com',
#  'ulta katespade.com',
#  'sephora strivectin.com',
#  'ulta foreo.com',
#  'ulta ancientnutrition.com',
#  'ulta sacheu.com',
#  'ulta milkandhoney.com',
#  'sephora patrickta.com',
#  'ulta hanscc.com',
#  'ulta bremennclinical.com',
#  'ulta ogxbeauty.com',
#  'ulta uomabeauty.com',
#  'ulta lolibeauty.com',
#  'ulta handinhandsoap.com',
#  'sephora athrbeauty.com',
#  'ulta crepeerase.com',
#  'ulta sooaenewyork.com',
#  'sephora jouercosmetics.com',
#  'ulta abbasite.com',
#  'ulta tomford.com',
#  'sephora phlur.com',
#  'sephora beautycounter.com',
#  'ulta cotzskincare.com',
#  'sephora isseymiyake.com',
#  'ulta dukecannon.com',
#  'sephora ediblebeautyaustralia.com',
#  'ulta completelybare.com',
#  'ulta nomostache.com',
#  'ulta carolsdaughter.com',
#  'sephora clinique.com',
#  'ulta spornette.com',
#  'ulta biore.com',
#  'ulta meaningfulbeauty.com',
#  'ulta mskincare.com',
#  'ulta sleekmakeup.com',
#  'ulta murad.com',
#  'ulta loopsbeauty.com',
#  'sephora drunkelephant.com',
#  'ulta itsa10haircare.com',
#  'ulta projectsunscreen.com',
#  'ulta cocoandeve.com',
#  'sephora jomalone.com',
#  'ulta nyxcosmetics.com',
#  'ulta littlebarnapothecary.com',
#  'sephora evelom.com',
#  'ulta triumphanddisaster.com',
#  'ulta mrbubble.com',
#  'sephora ysl.com',
#  'ulta dior.com',
#  'sephora drsturm.com',
#  'sephora drlaradevgan.com',
#  'ulta oscardelarenta.com',
#  'ulta dermadoctor.com',
#  'ulta bodybysol.com',
#  'ulta clinique.com',
#  'ulta thepopband.com',
#  'ulta fountainoftruthbeauty.com',
#  'ulta lipsmacker.com',
#  'ulta touchland.com',
#  'ulta gucci.com',
#  'ulta gofromm.com',
#  'ulta lanza.com',
#  'sephora verbproducts.com',
#  'sephora staywellkept.com',
#  'ulta homebodyworld.com',
#  'sephora mrmarvis.com',
#  'ulta kreyolessence.com',
#  'ulta koparibeauty.com',
#  'ulta serovital.com',
#  'sephora capri-blue.com',
#  'ulta dyson.com',
#  'ulta cerave.com',
#  'ulta ghdhair.com',
#  'ulta differin.com',
#  'ulta shiseido.com',
#  'sephora vernonfrancois.com',
#  'ulta beautyblender.com',
#  'ulta australianglow.com',
#  'ulta sandandsky.com',
#  'ulta blume.com',
#  'ulta evianspray.com',
#  'ulta lashfood.com',
#  'ulta labseries.com',
#  'ulta xout.com',
#  'ulta thecremeshop.com',
#  'sephora shiseido.com',
#  'ulta petitenpretty.com',
#  'ulta bic.com',
#  'ulta finishingtouchflawless.com',
#  'sephora acquadiparma.com',
#  'ulta cakemusic.com',
#  'sephora ateliercologne.com',
#  'ulta belliskincare.com',
#  'ulta elciecosmetics.com',
#  'ulta formula1006.com',
#  'sephora glowrecipe.com',
#  'ulta touchinsol-us.com',
#  'sephora mykitsch.com',
#  'sephora tan-luxe.com',
#  'ulta verawang.com',
#  'sephora roenbeauty.com',
#  'ulta perriconemd.com',
#  'ulta ihomeaudio.com',
#  'sephora selenagomez.com',
#  'ulta guerlain.com',
#  'ulta jergens.com',
#  'ulta billieeilish.com',
#  'sephora viktor-rolf.com',
#  'sephora chriscollins.com',
#  'sephora theordinaryskincareproducts.com',
#  'sephora mugler.com',
#  'ulta nailtek.com',
#  'sephora makeupforever.com',
#  'ulta exabeauty.com',
#  'ulta supersmile.com',
#  'sephora perriconemd.com',
#  'ulta urbandecay.com',
#  'ulta peachandlily.com',
#  'sephora lawlessbeauty.com',
#  'ulta pirette.com',
#  'ulta davidbeckham.com',
#  'ulta drbronner.com',
#  'sephora aerin.com',
#  'sephora rmsbeauty.com',
#  'ulta jeanpaulgaultier.com',
#  'ulta lovewellness.com',
#  'ulta designessentials.com',
#  'ulta kikocosmetics.com',
#  'sephora saiehello.com',
#  'ulta curlsmith.com',
#  'ulta gosmile.com',
#  'sephora duo.com',
#  'sephora lilahbeauty.com',
#  'sephora augustinusbader.com',
#  'sephora blackup.com',
#  'sephora proraso-usa.com',
#  'ulta schmidts.com',
#  'ulta seche.com',
#  'ulta aghair.com',
#  'ulta hustlebutter.com',
#  'sephora humnutrition.com',
#  'ulta h2oplus.com',
#  'ulta rizoscurls.com',
#  'ulta essence.com',
#  'ulta sunbum.com',
#  'ulta inuwet.com',
#  'sephora kajabeauty.com',
#  'sephora rosebudperfume.us',
#  'ulta staticnails.com',
#  'sephora prada.com',
#  'ulta zoevacosmetics.com',
#  'ulta revlon.com',
#  'sephora theisleofparadise.com',
#  'ulta purehealsusa.com',
#  'ulta get-harajuku-lovers.com',
#  'ulta drorganic.co.uk',
#  'ulta goldnhothair.com',
#  'ulta elizabetharden.com',
#  'ulta ruskhair.com',
#  'ulta mydentitycolor.com',
#  'ulta evolutionofsmooth.com',
#  'sephora moschino.com',
#  'sephora drybar.com',
#  'ulta baxterofcalifornia.com',
#  'ulta brookstone.com',
#  'sephora beachwaver.com',
#  'sephora hereticbrewing.com',
#  'sephora hourglasscosmetics.com',
#  'sephora groupeclarins.com',
#  'sephora katespade.com',
#  'ulta strivectin.com',
#  'ulta ouidad.com',
#  'sephora ouidad.com',
#  'sephora 54thrones.com',
#  'sephora farmacybeauty.com',
#  'sephora rodinoliolusso.com',
#  'ulta bareminerals.com',
#  'ulta delectable.com',
#  'ulta kitaomatcha.com',
#  'ulta dippitydomen.com',
#  'ulta bumbleandbumble.com',
#  'ulta innersensebeauty.com',
#  'sephora juicycouture.com',
#  'ulta livingproof.com',
#  'ulta repfitness.com',
#  'ulta undone-beauty.com',
#  'ulta definemefragrance.com',
#  'ulta indeedlabs.com',
#  'ulta rapidlash.com',
#  'ulta elle.com',
#  'ulta fakebake.com',
#  'ulta dolcegabbanabeauty.com',
#  'ulta vsbskincare.com',
#  'sephora tower28beauty.com',
#  'sephora touchinsol-us.com',
#  'ulta klairscosmetics.com',
#  'ulta kkwbeauty.com',
#  'ulta goodstuffmy.com',
#  'sephora goop.com',
#  'ulta niveausa.com',
#  'ulta travalo.com',
#  'sephora rossanoferretti.com',
#  'ulta skintimate.com',
#  'sephora labseries.com',
#  'sephora theartofshaving.com',
#  'sephora vitaliberata.com',
#  'ulta yunibeauty.com',
#  'ulta valentino.com',
#  'sephora stellar.org',
#  'sephora sallybeauty.com',
#  'sephora apivita.com',
#  'sephora biossance.com',
#  'ulta hollywoodfashionsecrets.com',
#  'sephora eightandbob.com',
#  'ulta ddfskincare.com',
#  'ulta michaeltoddbeauty.com',
#  'ulta kestrelinstruments.com',
#  'ulta elemis.com',
#  'ulta loreal.com',
#  'sephora voluspa.com',
#  'ulta vichyusa.com',
#  'sephora playabeauty.com',
#  'ulta barefootscientist.com',
#  'sephora paulaschoice.com',
#  'ulta skinyoga.in',
#  'ulta zitsticka.com',
#  'ulta ulta.com',
#  'sephora floraandbast.com',
#  'sephora vegamour.com',
#  'ulta mariobadescu.com',
#  'sephora aquis.com',
#  'sephora drsobelskinrx.com',
#  'ulta camillerose.com',
#  'ulta bravosierra.com',
#  'sephora kerastase.com',
#  'ulta keratincomplex.com',
#  'sephora dereklam.com',
#  'sephora bobbibrowncosmetics.com',
#  'ulta esquire.com',
#  'ulta jaclyncosmetics.com',
#  'ulta pattern.com',
#  'sephora coola.com',
#  'sephora jilliandempsey.com',
#  'ulta makeuperaser.com',
#  'ulta pinchprovisions.com',
#  'sephora belifusa.com',
#  'ulta olaplex.com',
#  'sephora primera.com',
#  'ulta drroebucks.com',
#  'ulta tymestyle.com',
#  'sephora chanel.com',
#  'ulta doubledare.com',
#  'sephora pmdbeauty.com',
#  'ulta lovekinship.com',
#  'ulta leestafford.com',
#  'ulta masonmanskincare.com',
#  'sephora floralstreet.com',
#  'sephora origins.com',
#  'ulta thehairedit.com',
#  'ulta conair.com',
#  'ulta getbeast.com',
#  'ulta mercihandy.com',
#  'ulta retinolbyrobanda.com',
#  'ulta cetaphil.com',
#  'ulta essie.com',
#  'ulta blinkingbeaute.com',
#  'sephora coalandcanary.com',
#  'ulta clarisonic.com',
#  'ulta anastasiabeverlyhills.com',
#  'sephora meltcosmetics.com',
#  'ulta phyto.com',
#  'ulta supergoop.com',
#  'sephora rahua.com',
#  'ulta kneipp.com',
#  'ulta chinaglaze.com',
#  'sephora stellamccartney.com',
#  'ulta arcticfoxhaircolor.com',
#  'ulta glam-addict.com',
#  'ulta pulleez.com',
#  'ulta tangleteezer.com',
#  'sephora shuuemuraartofhair-usa.com',
#  'sephora loccitane.com',
#  'ulta eva-nyc.com',
#  'ulta kvdveganbeauty.com',
#  'sephora lancerskincare.com',
#  'sephora kosas.com',
#  'ulta sugarpill.com',
#  'ulta juicycouture.com',
#  'ulta aveeno.com',
#  'sephora cellu-cup.com',
#  'ulta ora.organic',
#  'ulta better-notyounger.com',
#  'sephora sandandsky.com',
#  'ulta wigotekcomputers.com',
#  'sephora carolinaherrera.com',
#  'sephora dominiquecosmetics.com',
#  'ulta wldkat.com',
#  'sephora marcjacobs.com',
#  'sephora mybkr.com',
#  'ulta sallyhansen.com',
#  'ulta catrice.eu',
#  'ulta authenticbeautyconcept.us',
#  'sephora beautybio.com',
#  'sephora privatedoctorbeauty.com',
#  'ulta keranique.com',
#  'sephora tweezerman.com',
#  'ulta chloe.com',
#  'ulta exuviance.com',
#  'ulta wetnwildbeauty.com',
#  'ulta herocosmetics.us',
#  'sephora hermes.com',
#  'ulta biopelle.com',
#  'ulta armani.com',
#  'ulta lagirlusa.com',
#  'ulta daniellesteel.com',
#  'ulta burtsbees.com',
#  'sephora blincinc.com',
#  'ulta philips.com',
#  'ulta beccaswim.com',
#  'ulta tweezerman.com',
#  'sephora prettyvulgar.com',
#  'ulta skinfix.com',
#  'ulta noughtyhaircare.com',
#  'ulta milanicosmetics.com',
#  'sephora histoiresdeparfums.com',
#  'ulta colgate.com',
#  'ulta toppik.com',
#  'ulta meowmeowtweet.com',
#  'ulta hipchic.com',
#  'sephora boscia.com',
#  'ulta bikinizone.com',
#  'ulta secret.com',
#  'ulta megrhythmusa.com',
#  'ulta covergirl.com',
#  'sephora comptoirsudpacifique.us',
#  'sephora pureology.com',
#  'ulta mykitsch.com',
#  'ulta ereperez.com',
#  'ulta devacurl.com',
#  'ulta punky.com',
#  'sephora bareminerals.com',
#  'sephora thedlmd.com',
#  'ulta orlybeauty.com',
#  'ulta tginatural.com',
#  'ulta haskbeauty.com',
#  'sephora gooddyeyoung.com',
#  'sephora obagi.com',
#  'ulta acebeaute.com',
#  'sephora besamecosmetics.com',
#  'sephora drroebucks.com',
#  'ulta jessicasimpson.com',
#  'ulta npbeautiful.com',
#  'ulta specificbeauty.com',
#  'ulta hottools.com',
#  'ulta banilausa.com',
#  'sephora naturallyseriousskin.com',
#  'sephora kevynaucoinbeauty.com',
#  'sephora mysunday2sunday.com',
#  'ulta bioionic.com',
#  'sephora supergoop.com',
#  'ulta remington.com',
#  'ulta capri-blue.com',
#  'ulta philosophy.com',
#  'ulta inkedbydani.com',
#  'ulta elfcosmetics.com',
#  'ulta beekman1802.com',
#  'ulta coverfx.com',
#  'sephora coach.com',
#  'ulta billyjealousy.com',
#  'ulta weareparadoxx.com',
#  'sephora jlobeauty.com',
#  'ulta crest.com',
#  'ulta rikilovesriki.com',
#  'ulta rituals.com',
#  'ulta lipstickqueen.com',
#  'ulta johnfrieda.com',
#  'ulta lanolips.com',
#  'sephora surrattbeauty.com',
#  'ulta lbknails.com',
#  'sephora k18hair.com',
#  'sephora skylar.com',
#  'ulta korres.com',
#  'ulta marcanthony.com',
#  'ulta thayers.com',
#  'sephora getshaveworks.com',
#  'ulta poopourri.com',
#  'ulta baublebar.com',
#  'sephora sephora.com',
#  'sephora glamglow.com',
#  'ulta elaluz.com',
#  'ulta schick.com',
#  'ulta babobotanicals.com',
#  'ulta ellamila.com',
#  'ulta beccacosmetics.com',
#  'ulta gamaprofessional.us',
#  'ulta acure.com',
#  'ulta cargocosmetics.com',
#  'ulta persona.co',
#  'ulta cleanandclear.com',
#  'sephora ernolaszlo.com',
#  'ulta joico.com',
#  'ulta jolenbeauty.com',
#  'sephora stackedskincare.com',
#  'sephora mynuface.com',
#  'ulta ipknus.com',
#  'sephora narscosmetics.com',
#  'ulta sebastianprofessional.com',
#  'ulta tresemme.com',
#  'sephora kiehls.com',
#  'sephora damdamtokyo.com',
#  'ulta thann.us',
#  'sephora vitalproteins.com',
#  'sephora getjackblack.com',
#  'sephora summerfridays.com',
#  'ulta youngnails.com',
#  'ulta batistehair.com',
#  'ulta furyou.com',
#  'ulta isseymiyake.com',
#  'sephora elizabethandjames.us',
#  'ulta megababebeauty.com',
#  'ulta carolinaherrera.com',
#  'sephora christianlouboutin.com',
#  'sephora facegym.com',
#  'ulta balibodyco.com',
#  'sephora adwoabeauty.com',
#  'ulta eyeko.com',
#  'sephora givenchy.com',
#  'sephora makeupbymario.com',
#  'ulta myamazingproducts.com',
#  'ulta belifusa.com',
#  'ulta lavanila.com',
#  'sephora blinkingbeaute.com',
#  'ulta theskinfood.us',
#  'ulta frizzdefense.com',
#  'sephora fashionfair.com',
#  'sephora kayalifragrance.com',
#  'ulta narscosmetics.com',
#  'ulta toryburch.com',
#  'ulta marcjacobs.com',
#  'ulta skinnydipped.com',
#  'ulta prada.com',
#  'ulta kiehls.com',
#  'sephora maisonlouismarie.com',
#  'ulta urbanhydration.com',
#  'ulta thehandmadesoapcompany.com',
#  'sephora yunibeauty.com',
#  'ulta toofaced.com',
#  'ulta anthony.com',
#  'sephora renskincare.com',
#  'ulta diamondcosmetics.com',
#  'ulta moon.com',
#  'ulta slip.com',
#  'sephora breadbeautysupply.com',
#  'ulta kennethcole.com',
#  'ulta leminimacaron.com',
#  'ulta donnakaran.com',
#  'ulta loccitane.com',
#  'sephora toryburch.com',
#  'ulta lamikbeauty.com',
#  'ulta olay.com',
#  'ulta smithandcult.com',
#  'ulta my7thheaven.com',
#  'ulta coloroops.com',
#  'sephora melaninhaircare.com',
#  'ulta polder.com',
#  'ulta fifthandroot.com',
#  'sephora sakara.com',
#  'ulta caneandaustin.com',
#  'ulta dabombfizzers.com',
#  'ulta dermablend.com',
#  'ulta crichd.cricket',
#  'sephora christopherobin.com',
#  'sephora fentybeauty.com',
#  'ulta splathaircolor.com',
#  'ulta tigi.com',
#  'sephora moroccanoil.com',
#  'sephora lashfood.com',
#  'ulta yourtheorie.com',
#  'ulta juviasplace.com',
#  'sephora meritcoffee.com',
#  'sephora highbeauty.com',
#  'ulta blackmooncosmetics.com',
#  'sephora better-notyounger.com',
#  'ulta realtechniques.com',
#  'ulta wahl.com',
#  'sephora natashadenona.com',
#  'sephora welleco.com',
#  'ulta skinlabsf.com',
#  'ulta stmoriztan.com',
#  'ulta aquis.com',
#  'ulta aunaturalecosmetics.com',
#  'ulta numehair.com',
#  'ulta firstaidbeauty.com',
#  'ulta bronxcolors.biz',
#  'ulta pureology.com',
#  'ulta minetanbodyskin.com',
#  'ulta fourthraybeauty.com',
#  'sephora susteau.com',
#  'ulta biolage.com',
#  'sephora smashbox.com',
#  'sephora colorwowhair.com',
#  'sephora theinkeylist.com',
#  'ulta drunkelephant.com',
#  'sephora narcisorodriguez.com',
#  'sephora iloveskininc.us',
#  'sephora jimmychoo.com',
#  'ulta wetbrush.com',
#  'sephora t3micro.com',
#  'ulta olioeosso.com',
#  'ulta biosilk.com',
#  'ulta earththerapeutics.com',
#  'sephora toocoolforschool.us',
#  'ulta dashingdiva.com',
#  'sephora lululemon.com',
#  'sephora miumiu.com',
#  'ulta tendskin.com',
#  'sephora farsali.com',
#  'ulta viktor-rolf.com',
#  'sephora gloscience.com',
#  'ulta clarismabeauty.com',
#  'ulta johnvarvatos.com',
#  'sephora google.org',
#  'ulta purcosmetics.com',
#  'ulta pinrose.com',
#  'sephora youthtothepeople.com',
#  'ulta smartypits.com',
#  'ulta route.com',
#  'ulta amazingcosmetics.com',
#  'ulta ardellshop.com',
#  'ulta buttahskin.com',
#  'sephora nursejamie.com',
#  'ulta mauimoisture.com',
#  'sephora thenueco.com',
#  'ulta burberry.com',
#  'sephora daehair.com',
#  'ulta dailyconcepts.com',
#  'sephora keranique.com',
#  'ulta doahappydance.com',
#  'ulta hairuwear.com',
#  'ulta fairytaleshaircare.com',
#  'ulta tartecosmetics.com',
#  'sephora nailsinc.com',
#  'ulta memebox.com',
#  'ulta verbproducts.com',
#  'ulta naturesbounty.com',
#  'ulta sttropica.com',
#  'ulta wellpeople.com',
#  'ulta florencebymills.com',
#  'ulta sultra.com',
#  'ulta versace.com',
#  'ulta matrix.com',
#  'ulta pipettes.com',
#  'ulta nudestix.com',
#  'ulta beachwaver.com',
#  'ulta jrwatkins.com',
#  'ulta teamiblends.com',
#  'ulta homeworx.shop',
#  'ulta houseoflashes.com',
#  'sephora dphue.com',
#  'ulta janeiredale.com',
#  'sephora clarisonic.com',
#  'sephora foreo.com',
#  'sephora dyson.com',
#  'ulta beis.com',
#  'ulta thankyoufarmer.my',
#  'ulta sugarbearvitamincare.com',
#  'sephora yorkfair.org',
#  'sephora olehenriksen.com',
#  'ulta bosley.com',
#  'ulta beautybio.com',
#  'ulta beautybakerie.com',
#  'ulta drteals.com',
#  'sephora earthsnectar.com',
#  'ulta maneclubnyc.com',
#  'ulta miamica.com',
#  'ulta seedphytonutrients.com',
#  'sephora nomostache.com',
#  'ulta davidandyoung.com',
#  'ulta wunder2.com',
#  'ulta heyhoney.com',
#  'ulta leaders.jo',
#  'ulta lulubeautyco.com',
#  'sephora antonym.com',
#  'sephora livingproof.com',
#  'ulta guylaroche.com',
#  'ulta sorbushome.com',
#  'sephora neogenlab.us',
#  'ulta keyssoulcare.com',
#  'ulta biomega.com',
#  'ulta sunshineglitter.com',
#  'sephora igkhair.com',
#  'sephora danessamyricksbeauty.com',
#  'ulta fresh.com',
#  'ulta storybookcosmetics.com',
#  'ulta base-4.com',
#  'ulta arcona.com',
#  'ulta holikaholika.ca',
#  'ulta nickstensonbeauty.com',
#  'sephora beccaswim.com',
#  'sephora viseartparis.com',
#  'ulta bar-none.com',
#  'ulta naturalicious.net',
#  'ulta physiciansformula.com',
#  'ulta bioclarity.com',
#  'ulta viviscal.com',
#  'ulta upcirclebeauty.com',
#  'sephora lavanila.com',
#  'sephora refausa.com',
#  'ulta blissworld.com',
#  'sephora ciatelondon.com',
#  'sephora herbivorebotanicals.com',
#  'sephora shophush.com',
#  'ulta babyfoot.com',
#  'ulta bhcosmetics.com',
#  'ulta dermelect.com',
#  'ulta dermalogica.com',
#  'ulta dermaflash.com',
#  'sephora ritahazan.com',
#  'sephora sachajuan.com',
#  'ulta capellinewyork.com',
#  'ulta pacificabeauty.com',
#  'ulta peterthomasroth.com',
#  'sephora drzenovia.com',
#  'ulta basdbodycare.com',
#  'ulta spektrumrc.com',
#  'ulta hallyhair.com',
#  'ulta thrivecausemetics.com',
#  'sephora saturdayskin.com',
#  'ulta rosebudperfume.us',
#  'sephora korres.com',
#  'ulta captainblankenship.com',
#  'ulta goodmolecules.com',
#  'ulta julep.com',
#  'ulta livetinted.com',
#  'ulta chi.com',
#  'sephora blithecosmetic.com',
#  'sephora moonjuice.com',
#  'ulta nursejamie.com',
#  'ulta coveryourgray.com',
#  'ulta elevenbyvenuswilliams.com',
#  'ulta hairfood.com',
#  'sephora bykilian.com',
#  'sephora rituals.com',
#  'sephora drbrandtskincare.com',
#  'ulta naturallyg4u.com',
#  'ulta ofracosmetics.com',
#  'ulta velourbeauty.com',
#  'ulta funko.com',
#  'ulta giorgioarmanibeauty-usa.com',
#  'sephora pinrose.com',
#  'sephora valentino.com',
#  'ulta livehoneybelle.com',
#  'ulta curls.biz',
#  'ulta drpawpaw.com',
#  'sephora incredible.co.za',
#  'ulta americancrew.com',
#  'ulta bio-oil.com',
#  'ulta voltlighting.com',
#  'ulta tpsy.com',
#  'ulta popsugar.com',
#  'ulta tan-luxe.com',
#  'ulta sarahapp.com',
#  'ulta naterra.com',
#  'ulta winkylux.com',
#  'ulta bondiboost.com',
#  'ulta flowerbeauty.com',
#  'sephora shanidarden.com',
#  'sephora the7virtues.com',
#  'ulta soapandglory.com',
#  'sephora cinemasecrets.com',
#  'ulta nyakio.com',
#  'ulta buxomcosmetics.com',
#  'sephora dermalogica.com',
#  'sephora theouai.com',
#  'ulta tanologist.com',
#  'ulta trulyorganic.com',
#  'sephora rosemdskin.com',
#  'sephora lancome.com',
#  'ulta coola.com',
#  'sephora conture.com',
#  'ulta andalou.com',
#  'ulta esteelauder.com',
#  'ulta sexyhair.com',
#  'ulta colourpop.com',
#  'ulta sheamoisture.com',
#  'ulta kocostarusa.com',
#  'sephora mcjwbeautyculture.com',
#  'ulta mannakadarbeauty.com',
#  'ulta glamglow.com',
#  'ulta ecotools.com',
#  'ulta ursamajorvt.com',
#  'ulta blackgirlsunscreen.com',
#  'ulta minerva.edu',
#  'sephora forvrmood.com',
#  'ulta eylure.com',
#  'sephora tangleteezer.com',
#  'ulta snpcos.us',
#  'sephora invisibobble.com',
#  'ulta gillette.com',
#  'sephora lillylashes.com',
#  'ulta t3micro.com',
#  'ulta sohosb.com',
#  'ulta dhccare.com',
#  'ulta mauibabe.com',
#  'sephora cocofloss.com',
#  'sephora proactiv.com',
#  'ulta maybelline.com',
#  'sephora michaelkors.com',
#  'ulta eczemahoneyco.com',
#  'sephora virtuelabs.com',
#  'ulta turbietwist.com',
#  'ulta opi.com',
#  'sephora winkylux.com',
#  'sephora patternbeauty.com',
#  'ulta weleda.com',
#  'ulta itcosmetics.com',
#  'sephora itsskinusa.com',
#  'ulta beautystatcosmetics.com',
#  'sephora volitionbeauty.com',
#  'ulta onbeing.org',
#  'ulta iconiclondoninc.com',
#  'sephora 8greens.com',
#  'sephora marcjacobsfragrances.com',
#  'ulta mixedchicks.net',
#  'ulta pacorabanne.com',
#  'sephora sulwhasoo.com',
#  'sephora togetherbeauty.com',
#  'ulta bawdybeauty.com',
#  'ulta inhhair.com',
#  'ulta hipdot.com',
#  'ulta londontownusa.com',
#  'ulta beautygems.com',
#  'ulta herbalessences.com',
#  'sephora blendsmart.com',
#  'ulta tula.com',
#  'sephora touchland.com',
#  'ulta sundayriley.com',
#  'ulta niahealthcare.com',
#  'ulta smashbox.com',
#  'ulta thickhead.com',
#  'ulta oralb.com',
#  'sephora westman-atelier.com',
#  'ulta cosrx.com',
#  'sephora goto.com',
#  'ulta irohanature.us',
#  'sephora drjart.com',
#  'ulta zoya.com',
#  'ulta gigispa.com',
#  'ulta nioxin.com',
#  'ulta mysunday2sunday.com',
#  'ulta theflowery.co',
#  'ulta dionisgmskincare.com',
#  'ulta axiologybeauty.com',
#  'ulta glamnetic.com',
#  'sephora ellisbrooklyn.com',
#  'ulta michaelkors.com',
#  'sephora kenzoparfums.com',
#  'ulta hourglasscosmetics.com',
#  'ulta theouai.com',
#  'ulta langehair.com',
#  'ulta fslaser.com',
#  'ulta graceeleyae.com',
#  'ulta pravana.com',
#  'ulta urbanveda.com',
#  'sephora lordjones.com',
#  'ulta drybar.com',
#  'ulta melaninhaircare.com',
#  'sephora selflessbyhyram.com',
#  'ulta oliviagarden.com',
#  'ulta stmntgrooming.us',
#  'ulta curel.com',
#  'ulta bulgari.com',
#  'sephora berdoues.com',
#  'sephora lunarbeauty.com',
#  'ulta artnaturals.com',
#  'ulta noyah.com',
#  'ulta aquage.com',
#  'sephora seedphytonutrients.com',
#  'sephora briogeohair.com',
#  'ulta ritueldefille.com',
#  'sephora velourbeauty.com',
#  'ulta gimmebeauty.com',
#  'ulta bondisands.com',
#  'ulta macadamiahair.com',
#  'sephora olaplex.com',
#  'ulta kloraneusa.com',
#  'sephora innisfree.com',
#  'sephora juliettehasagun.com',
#  'sephora refybeauty.com',
#  'ulta chapstick.com',
#  'ulta butterlondon.com',
#  'ulta garnier.ca',
#  'ulta lipbang.com',
#  'ulta growgorgeous.com',
#  'ulta sign-tribe.com',
#  'sephora sk-ii.com',
#  'ulta neumabeauty.com',
#  ...]

# %%
job_config = bigquery.QueryJobConfig(
    query_parameters=[
        bigquery.ScalarQueryParameter("prev_date", "STRING", prev_date),
        bigquery.ArrayQueryParameter("revSource", "STRING", rev_source)
    ]
)
review_query = """
    SELECT distinct source_name,
    normalized_url,
    FROM `helio-staging.online_reviews.online_reviews__deduped_review__1_0`
    WHERE source_name in UNNEST (@revSource)
    AND normalized_url IS NOT NULL
    AND execution_date = @prev_date
    """
query_job = client.query(
    review_query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
    job_config=job_config
)  # API request - starts the query

prev_brands = query_job.to_dataframe()
prev_brands = prev_brands.loc[prev_brands.astype(str).drop_duplicates().index]
prev_brands["combined"] = prev_brands["source_name"] +" "+prev_brands["normalized_url"] 
prev_brands = prev_brands["combined"].tolist()

# %%
new_brands = [x for x in brands if x not in prev_brands]

# %%
new_brands
# Out:
# ['ulta teraxhaircare.com']

# %%
job_config = bigquery.QueryJobConfig(
    query_parameters=[
        bigquery.ScalarQueryParameter("prev_date", "STRING", prev_date),
        bigquery.ArrayQueryParameter("revSource", "STRING", rev_source)
    ]
)
review_query = """
    SELECT distinct source_name,
    normalized_url,
    FROM `helio-staging.online_reviews.online_reviews__deduped_review__1_0`
    WHERE source_name in UNNEST (@revSource)
    AND normalized_url IS NOT NULL
    AND execution_date = @prev_date
    """
query_job = client.query(
    review_query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
    job_config=job_config
)  # API request - starts the query

newbrands = query_job.to_dataframe()
newbrands = newbrands.loc[newbrands.astype(str).drop_duplicates().index]

# %%
newbrands
# Out:
#      source_name       normalized_url
# 0           ulta        loccitane.com
# 1           ulta         mynuface.com
# 2        sephora   rodinoliolusso.com
# 3           ulta         babyfoot.com
# 4           ulta       johnfrieda.com
# ...          ...                  ...
# 1199        ulta             goli.com
# 1200        ulta    niahealthcare.com
# 1201        ulta    themanechoice.com
# 1202     sephora           drjart.com
# 1203     sephora  christopherobin.com
#
# [1204 rows x 2 columns]

# %%
rev_source = ["sephora","ulta"]

job_config = bigquery.QueryJobConfig(
        query_parameters=[
            bigquery.ArrayQueryParameter("revSource", "STRING", rev_source)
        ]
)
max_date_query = """
    SELECT DISTINCT execution_date
    FROM `helio-staging.online_reviews.online_reviews__deduped_review__1_0`
    where execution_date > DATE_ADD(current_date(), INTERVAL -365 DAY)
    and normalized_url IS NOT NULL
    ORDER BY execution_date DESC
    """
query_job = client.query(
    max_date_query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
    job_config=job_config
)  # API request - starts the query

list_of_dates = query_job.to_dataframe()

# %%
list_of_dates
# Out:
#     execution_date
# 0       2022-03-23
# 1       2022-03-22
# 2       2022-03-21
# 3       2022-03-20
# 4       2022-03-19
# ..             ...
# 278     2021-04-29
# 279     2021-04-25
# 280     2021-04-11
# 281     2021-04-04
# 282     2021-03-28
#
# [283 rows x 1 columns]

# %%
for i in list_of_dates:
    current_date = i
    job_config = bigquery.QueryJobConfig(
        query_parameters=[
            bigquery.ScalarQueryParameter("current_date", "STRING", current_date),
            bigquery.ArrayQueryParameter("revSource", "STRING", rev_source)
        ]
    )
    review_query = """
        SELECT count(distinct source_name || normalized_url)
        FROM `helio-staging.online_reviews.online_reviews__deduped_review__1_0`
        WHERE source_name in UNNEST (@revSource)
        AND execution_date = @current_date
        """
    query_job = client.query(
        review_query,
        # Location must match that of the dataset(s) referenced in the query.
        location="US",
        job_config=job_config
    )  # API request - starts the query

    brands = query_job.to_dataframe()
    brands = reviews.loc[reviews.astype(str).drop_duplicates().index]
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /tmp/ipykernel_21546/539443294.py in <module>
#      20     )  # API request - starts the query
#      21
# ---> 22     brands = query_job.to_dataframe()
#      23     brands = reviews.loc[reviews.astype(str).drop_duplicates().index]
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, date_as_object, max_results, geography_as_object)
#    1638                 :mod:`shapely` library cannot be imported.
#    1639         """
# -> 1640         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1641         return query_result.to_dataframe(
#    1642             bqstorage_client=bqstorage_client,
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#      86     )
#      87     if progress_bar is None:
# ---> 88         return query_job.result(max_results=max_results)
#      89
#      90     i = 0
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1445                 do_get_result = job_retry(do_get_result)
#    1446
# -> 1447             do_get_result()
#    1448
#    1449         except exceptions.GoogleAPICallError as exc:
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     286                 sleep_generator,
#     287                 self._deadline,
# --> 288                 on_error=on_error,
#     289             )
#     290
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     188     for sleep in sleep_generator:
#     189         try:
# --> 190             return target()
#     191
#     192         # pylint: disable=broad-except
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1435                     self._job_retry = job_retry
#    1436
# -> 1437                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1438
#    1439                 # Since the job could already be "done" (e.g. got a finished job
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     725
#     726         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 727         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     728
#     729     def cancelled(self):
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/future/polling.py in result(self, timeout, retry)
#     135             # pylint: disable=raising-bad-type
#     136             # Pylint doesn't recognize that this is valid in this case.
# --> 137             raise self._exception
#     138
#     139         return self._result
#
# BadRequest: 400 Cannot query over table 'helio-staging.online_reviews.online_reviews__deduped_review__1_0' without a filter over column(s) 'execution_date' that can be used for partition elimination
#
# (job ID: 33f2f8c5-c75c-4ce7-b378-bd1f4513fcb9)
#
#                           -----Query Job SQL Follows-----
#
#     |    .    |    .    |    .    |    .    |    .    |    .    |    .    |
#    1:
#    2:        SELECT count(distinct source_name || normalized_url)
#    3:        FROM `helio-staging.online_reviews.online_reviews__deduped_review__1_0`
#    4:        WHERE source_name in UNNEST (@revSource)
#    5:        AND execution_date = @current_date
#    6:
#     |    .    |    .    |    .    |    .    |    .    |    .    |    .    |
